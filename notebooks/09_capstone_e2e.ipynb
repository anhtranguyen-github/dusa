# %% [markdown]
# # Buổi 9 — Capstone: End-to-End System
#
# ## Agenda
# - DocLayout-YOLO → MixNet → PARSeq → KIE → FastAPI.
# - At least one KIE backend deployed (Triton or vLLM).
# - Report: F1 per field, E2E latency, throughput.
# - Mentor review checkpoint.

# %%
# Imports
