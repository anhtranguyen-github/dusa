# %% [markdown]
# # Buổi 9 — Capstone E2E
#
# Deliverable spec — see `docs/MasterClass …pdf`.

# %%
# %%writefile requirements/buoi-9.txt
# torch>=2.2
# transformers>=4.40
# fastapi
# uvicorn
# tritonclient[grpc,http]
# vllm
# matplotlib
# tqdm

# %%
import shutil, subprocess, sys
if shutil.which("uv") is None:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "uv"])
subprocess.check_call(["uv", "pip", "install", "--system", "-q",
                       "-r", "requirements/buoi-9.txt"])

# %% [markdown]
# ## Agenda
#
# - Capstone E2E: Layout → OCR → KIE → FastAPI; F1 + latency + throughput report.
