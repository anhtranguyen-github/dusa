# %% [markdown]
# # Buổi 4 — Qwen2.5-3B KIE (zero-shot → QLoRA)
#
# ## Agenda
# - Qwen2.5-3B architecture: GQA, RoPE, sliding window.
# - STEP 1 — Zero-shot prompt → JSON; eval Macro F1.
# - If F1 ≥ 0.85: stop. Else STEP 2 — build instruction dataset, QLoRA fine-tune.
# - Save LoRA adapter → KIE backend #2.

# %%
# Imports
