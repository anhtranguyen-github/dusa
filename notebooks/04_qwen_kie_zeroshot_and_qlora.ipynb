# %% [markdown]
# # Buổi 4 — LLM & Qwen2.5-3B KIE
#
# Deliverable spec — see `docs/MasterClass …pdf`.

# %%
# %%writefile requirements/buoi-4.txt
# torch>=2.2
# transformers>=4.40
# datasets
# peft
# trl
# accelerate
# bitsandbytes
# sentencepiece
# matplotlib
# tqdm

# %%
import shutil, subprocess, sys
if shutil.which("uv") is None:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "uv"])
subprocess.check_call(["uv", "pip", "install", "--system", "-q",
                       "-r", "requirements/buoi-4.txt"])

# %% [markdown]
# ## Agenda
#
# - Qwen2.5-3B zero-shot KIE eval; QLoRA fine-tune only if Macro F1 < 0.85.
# - Output: zero-shot report; LoRA adapter (conditional).
