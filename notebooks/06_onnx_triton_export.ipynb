# %% [markdown]
# # Buổi 6 — ONNX & Triton
#
# Deliverable spec — see `docs/MasterClass …pdf`.

# %%
# %%writefile requirements/buoi-6.txt
# torch>=2.2
# transformers>=4.40
# onnx>=1.16
# onnxruntime
# onnxruntime-gpu
# tritonclient[grpc,http]
# matplotlib
# tqdm

# %%
import shutil, subprocess, sys
if shutil.which("uv") is None:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "uv"])
subprocess.check_call(["uv", "pip", "install", "--system", "-q",
                       "-r", "requirements/buoi-6.txt"])

# %% [markdown]
# ## Agenda
#
# - Export PARSeq + LayoutLMv3 to ONNX; deploy on Triton; benchmark latency.
