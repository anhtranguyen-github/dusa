# %% [markdown]
# # Buổi 6 — ONNX & Triton Inference Server
#
# ## Agenda
# - Export PARSeq → ONNX; validate with Netron.
# - Export LayoutLMv3 → ONNX; validate.
# - Deploy both on Triton (onnxruntime backend).
# - Benchmark: PyTorch vs ONNX Runtime vs Triton.

# %%
# Imports
