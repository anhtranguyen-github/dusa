# %% [markdown]
# # Buổi 10 — Demo & Wrap-up
#
# ## Agenda
# - Live demo via Swagger UI (or frontend).
# - Architecture defense (10–15 min/team).
# - Trends: GOT-OCR 2.0, DocOwl2, Document Agent.
# - Personal roadmap: Multimodal LLM, RAG + Doc AI, agentic pipeline.

# %%
# Imports
