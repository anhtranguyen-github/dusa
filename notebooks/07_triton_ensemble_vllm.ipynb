# %% [markdown]
# # Buổi 7 — Triton Ensemble + vLLM
#
# ## Agenda
# - Triton dynamic batching, Python backend, Ensemble DAG.
# - vLLM PagedAttention + continuous batching for Qwen2.5-3B.
# - Dockerfile + docker-compose for full stack.
# - Warmup scripts for both models.

# %%
# Imports
