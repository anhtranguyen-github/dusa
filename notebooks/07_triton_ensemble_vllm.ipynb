# %% [markdown]
# # Buổi 7 — Triton Ensemble + vLLM + FastAPI (1)
#
# Deliverable spec — see `docs/MasterClass …pdf`.

# %%
# %%writefile requirements/buoi-7.txt
# torch>=2.2
# transformers>=4.40
# vllm
# fastapi
# uvicorn
# tritonclient[grpc,http]
# pydantic>=2
# tqdm

# %%
import shutil, subprocess, sys
if shutil.which("uv") is None:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "uv"])
subprocess.check_call(["uv", "pip", "install", "--system", "-q",
                       "-r", "requirements/buoi-7.txt"])

# %% [markdown]
# ## Agenda
#
# - Triton Ensemble DAG + vLLM serve Qwen2.5-3B; FastAPI skeleton.
