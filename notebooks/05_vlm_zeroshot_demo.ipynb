# %% [markdown]
# # Buổi 5 — Vision-Language Models
#
# Deliverable spec — see `docs/MasterClass …pdf`.

# %%
# %%writefile requirements/buoi-5.txt
# torch>=2.2
# transformers>=4.40
# pillow
# matplotlib
# opencv-python
# tqdm
# accelerate
# sentencepiece

# %%
import shutil, subprocess, sys
if shutil.which("uv") is None:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "uv"])
subprocess.check_call(["uv", "pip", "install", "--system", "-q",
                       "-r", "requirements/buoi-5.txt"])

# %% [markdown]
# ## Agenda
#
# - VLM theory (GLM-OCR, LightonOCR, Nanonets-OCR) + zero-shot demo.
# - No fine-tune; report trade-offs vs traditional pipeline.
