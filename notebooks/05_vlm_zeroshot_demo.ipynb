# %% [markdown]
# # Buổi 5 — Vision-Language Models (theory + demo)
#
# ## Agenda
# - VLM architecture: Vision Encoder + Connector + LLM Decoder.
# - Survey: GLM-OCR, LightonOCR, Chandra-OCR, Nanonets-OCR.
# - Zero-shot Nanonets-OCR on a few SROIE images.
# - Trade-off table: VLM vs traditional pipeline (accuracy/latency/cost/data).

# %%
# Imports
