# %% [markdown]
# # Buổi 8 — FastAPI Dual-Backend (2)
#
# Deliverable spec — see `docs/MasterClass …pdf`.

# %%
# %%writefile requirements/buoi-8.txt
# fastapi
# uvicorn[standard]
# python-multipart
# pydantic>=2
# httpx
# tritonclient[grpc,http]
# matplotlib

# %%
import shutil, subprocess, sys
if shutil.which("uv") is None:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "uv"])
subprocess.check_call(["uv", "pip", "install", "--system", "-q",
                       "-r", "requirements/buoi-8.txt"])

# %% [markdown]
# ## Agenda
#
# - FastAPI POST /kie?backend={layoutlmv3|qwen}; throughput benchmark; Swagger demo.
