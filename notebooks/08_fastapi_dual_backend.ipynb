# %% [markdown]
# # Buổi 8 — FastAPI Dual-Backend KIE API
#
# ## Agenda
# - Async endpoints; Triton gRPC client + vLLM HTTP client.
# - POST /kie?backend={layoutlmv3|qwen} — wire to real models.
# - Health check, /models/status, Swagger UI.
# - Benchmark throughput: 10 concurrent × 2 backends.

# %%
# Imports
