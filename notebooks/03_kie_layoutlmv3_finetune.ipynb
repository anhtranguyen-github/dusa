# %% [markdown]
# # Buổi 3 — KIE: LayoutLMv3 Fine-tune
#
# Deliverable spec — see `docs/MasterClass …pdf`.

# %%
# %%writefile requirements/buoi-3.txt
# torch>=2.2
# torchvision
# transformers>=4.40
# seqeval
# datasets
# opencv-python
# pillow
# numpy
# pyyaml
# matplotlib
# tqdm

# %%
import shutil, subprocess, sys
if shutil.which("uv") is None:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "uv"])
subprocess.check_call(["uv", "pip", "install", "--system", "-q",
                       "-r", "requirements/buoi-3.txt"])

# %% [markdown]
# ## Agenda
#
# - LayoutLMv3 fine-tune for KIE on SROIE.
# - Input: OCR JSON from S2. Output: `layoutlmv3_sroie_kie.bin`, F1 per field.
