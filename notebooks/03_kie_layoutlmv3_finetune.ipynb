# %% [markdown]
# # Buổi 3 — KIE: LayoutLMv3 fine-tune
#
# ## Agenda
# - BIO tagging on documents; spatial + visual + text features.
# - Tokenize + align bbox with WordPiece.
# - Fine-tune LayoutLMv3 on SROIE Task 3 (4 fields).
# - F1 per field + Exact Match; save checkpoint → KIE backend #1.

# %%
# Imports
